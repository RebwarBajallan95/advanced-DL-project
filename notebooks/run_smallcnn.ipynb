# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Clone project from github
#! rm -r advanced-DL-project
! git clone "https://github.com/RebwarBajallan95/advanced-DL-project"
! cd advanced-DL-project

import os
os.chdir("./advanced-DL-project")
# Out:
# fatal: destination path 'advanced-DL-project' already exists and is not an empty directory.

# %%
import torch
from torch.autograd import Variable
import torchvision
import torchvision.transforms as transforms
from mimo_smallcnn import mimo_smallcnn

# %load_ext autoreload
# %autoreload 2

torch.backends.cudnn.benchmark = True

# set seed
torch.manual_seed(0)
# set torch.device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Print to see if you have GPU available, if no GPU => change colab runtime
print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6220/889882601.py in <module>
#       3 import torchvision
#       4 import torchvision.transforms as transforms
# ----> 5 from mimo_smallcnn import mimo_smallcnn
#       6
#       7 get_ipython().run_line_magic('load_ext', 'autoreload')
#
# ModuleNotFoundError: No module named 'mimo_smallcnn'

# %%
cifar10_mean = (0.4914, 0.4822, 0.4465) 
cifar10_std = (0.2470, 0.2435, 0.2616)

#cifar10_mean = (0.5, 0.5, 0.5) 
#cifar10_std = (0.5, 0.5, 0.5)

# Image preprocessing modules
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize(cifar10_mean, cifar10_std)])

batch_size = 128

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(
                                        trainset, 
                                        batch_size=batch_size,
                                        shuffle=True, 
                                        pin_memory=True,
                                        drop_last=True, 
                                        
                                    )

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
                                       
testloader = torch.utils.data.DataLoader(
                                    testset, 
                                    batch_size=batch_size,
                                    shuffle=False,
                                    pin_memory=True,
                                )

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import numpy as np
from mimo_smallcnn import mimo_smallcnn

# %load_ext autoreload
# %autoreload 2

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = mimo_smallcnn(
    input_shape=(3, 3, 32, 32), # NOTE: PyTorch expects (n_samples, channels, height, width)
    num_classes=10,
    ensemble_size=3,
    batch_repitition=4
).to(device)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model.running_stats
# Out:
# {}

# %%
torch.cuda.empty_cache()
model.fit(
        trainloader, 
        testloader, 
        epochs=40, 
        trainset_size=len(trainset), 
        batch_size=batch_size
    )
# Out:
# Learning rate:  [0.001]
# Epoch:  0
# Training Loss: 6.9081397239978495
# Testing Accuracy: 13.34
# Testing loss: 2.2969433023959778
# Learning rate:  [0.001]
# Epoch:  1
# Training Loss: 6.856426921257606
# Testing Accuracy: 16.86
# Testing loss: 2.268291153485262
# Learning rate:  [0.001]
# Epoch:  2
# Training Loss: 6.7375821138039615
# Testing Accuracy: 19.84
# Testing loss: 2.2153500846669645
# Learning rate:  [0.001]
# Epoch:  3
# Training Loss: 6.577493057495508
# Testing Accuracy: 21.11
# Testing loss: 2.1680324681197543
# Learning rate:  [0.001]
# Epoch:  4
# Training Loss: 6.45745520347204
# Testing Accuracy: 22.42
# Testing loss: 2.1244093481498427
# Learning rate:  [0.001]
# Epoch:  5
# Training Loss: 6.331809630760779
# Testing Accuracy: 23.14
# Testing loss: 2.089142066013964
# Learning rate:  [0.001]
# Epoch:  6
# Training Loss: 6.225836083827875
# Testing Accuracy: 24.25
# Testing loss: 2.0605568825444087
# Learning rate:  [0.001]
# Epoch:  7
# Testing Accuracy: 34.699999999999996
# Testing loss: 1.8340824721734734
# Learning rate:  [0.00025]
# Epoch:  27
# Training Loss: 5.494792677805974
# Testing Accuracy: 34.2
# Testing loss: 1.8237938850740842
# Learning rate:  [0.00025]
# Epoch:  28
# Training Loss: 5.474137748816075
# Testing Accuracy: 34.589999999999996
# Testing loss: 1.8249790245973612
# Learning rate:  [0.00025]
# Epoch:  29
# Training Loss: 5.477521761869773
# Testing Accuracy: 34.870000000000005
# Testing loss: 1.8176548028294044
# Learning rate:  [0.000125]
# Epoch:  30
# Training Loss: 5.457793472974728
# Testing Accuracy: 34.98
# Testing loss: 1.8169638808769515
# Learning rate:  [0.000125]
# Epoch:  31
# Training Loss: 5.4504668993827625
# Testing Accuracy: 35.13
# Testing loss: 1.8171085466312458
# Learning rate:  [0.000125]
# Epoch:  32
# Training Loss: 5.4494612718239805
# Testing Accuracy: 35.42
# Testing loss: 1.8123119450822662
# Learning rate:  [0.000125]
# Epoch:  33
# Training Loss: 5.43687436519525
# Testing Accuracy: 35.42
# Testing loss: 1.8099034481410738
# Learning rate:  [0.000125]
# Epoch:  34
# Training Loss: 5.441164405529316
# Testing Accuracy: 34.92
# Testing loss: 1.8105280731297746
# Learning rate:  [0.000125]
# Epoch:  35
# Training Loss: 5.423690281158838
# Testing Accuracy: 34.86
# Testing loss: 1.8101714789112913
# Learning rate:  [0.000125]
# Epoch:  36
# Training Loss: 5.41949707422501
# Testing Accuracy: 35.370000000000005
# Testing loss: 1.8045600094372714
# Learning rate:  [0.000125]
# Epoch:  37
# Training Loss: 5.419613367471939
# Testing Accuracy: 35.35
# Testing loss: 1.8055972585195228
# Learning rate:  [0.000125]
# Epoch:  38
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4662/218258880.py in <module>
#       5         epochs=50,
#       6         trainset_size=len(trainset),
# ----> 7         batch_size=batch_size
#       8     )
#
# ~/advanced-DL-project/mimo_smallcnn.py in fit(self, trainloader, testloader, batch_size, trainset_size, epochs, save_mode_epochs, verbose)
#     159                 for _ in range(self.ensemble_size):
#     160                     # get random sample batch from training set
# --> 161                     x, y = next(training_iterator)
#     162                     # map to cuda if GPU available
#     163                     x = x.to(next(self.parameters()).device)
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /opt/conda/lib/python3.7/site-packages/torchvision/datasets/cifar.py in __getitem__(self, index)
#     118
#     119         if self.transform is not None:
# --> 120             img = self.transform(img)
#     121
#     122         if self.target_transform is not None:
#
# /opt/conda/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      58     def __call__(self, img):
#      59         for t in self.transforms:
# ---> 60             img = t(img)
#      61         return img
#      62
#
# /opt/conda/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#      95             Tensor: Converted image.
#      96         """
# ---> 97         return F.to_tensor(pic)
#      98
#      99     def __repr__(self):
#
# /opt/conda/lib/python3.7/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#     127     mode_to_nptype = {'I': np.int32, 'I;16': np.int16, 'F': np.float32}
#     128     img = torch.from_numpy(
# --> 129         np.array(pic, mode_to_nptype.get(pic.mode, np.uint8), copy=True)
#     130     )
#     131
#
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py in __array__(self, dtype)
#     696             new["data"] = self.tobytes("raw", "L")
#     697         else:
# --> 698             new["data"] = self.tobytes()
#     699
#     700         class ArrayData:
#
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py in tobytes(self, encoder_name, *args)
#     742             args = self.mode
#     743
# --> 744         self.load()
#     745
#     746         # unpack data
#
# KeyboardInterrupt:

# %%
import gc
  
gc.collect()
torch.cuda.empty_cache()
